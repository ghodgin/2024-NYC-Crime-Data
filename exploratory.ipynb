# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
crime_df = pd.read_csv('data/NYPD_Arrest_Data__Year_to_Date.csv')
crime_df.shape
# Out:
# (63621, 19)

# %%
crime_df.head(5)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2   279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3   280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4   280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                       ROBBERY  PL 1601001          F           M
# 1                          RAPE  PL 1303501          F           K
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
# 3               DANGEROUS DRUGS  PL 2200300          M           B
# 4                FELONY ASSAULT  PL 1200502          F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
## Shows all unique categories in the PD_DESC column, put categories into its own txt file for potential future use

unique_crimes = sorted(crime_df['PD_DESC'].unique())
unique_crimes
# Out:
# ['(null)',
#  'A.B.C.,FALSE PROOF OF AGE',
#  'ACCOSTING,FRAUDULENT',
#  'ADM.CODE,UNCLASSIFIED MISDEMEA',
#  'ADM.CODE,UNCLASSIFIED VIOLATIO',
#  'AGGRAVATED CRIMINAL CONTEMPT',
#  'AGGRAVATED GRAND LARCENY OF ATM',
#  'AGGRAVATED HARASSMENT 1',
#  'AGGRAVATED HARASSMENT 2',
#  'AGGRAVATED SEXUAL ASBUSE',
#  'AGRICULTURE & MARKETS LAW,UNCL',
#  'ALCOHOLIC BEVERAGE CONTROL',
#  'ALCOHOLIC BEVERAGE CONTROL LAW',
#  'ALCOHOLIC BEVERAGES,PUBLIC CON',
#  'ARSON 2,3,4',
#  'ASSAULT 2,1,UNCLASSIFIED',
#  'ASSAULT 3',
#  'ASSAULT POLICE/PEACE OFFICER',
#  'ASSEMBLY,UNLAWFUL',
#  'BAIL JUMPING 1 & 2',
#  'BAIL JUMPING 3',
#  'BRIBERY,COMMERCIAL',
#  'BRIBERY,FRAUD',
#  'BRIBERY,PUBLIC ADMINISTRATION',
#  'BURGLARS TOOLS,UNCLASSIFIED',
#  'BURGLARY,RESIDENCE,NIGHT',
#  'BURGLARY,UNCLASSIFIED,UNKNOWN',
#  'CANNABIS POSSESSION',
#  'CANNABIS POSSESSION, 2&1',
#  'CANNABIS POSSESSION, 3',
#  'CANNABIS SALE, 2&1',
#  'CANNABIS SALE, 3',
#  'CAUSE SPI/KILL ANIMAL',
#  'CHECK,BAD',
# ...

# %%
crime_df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1       279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2       279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3       280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4       280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...           ...         ...    ...                             ...    ...
# 63616   282877412  02/27/2024  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 63617   283628088  03/12/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 63618   283387006  03/07/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 63619   283013910  03/01/2024  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 63620   283495531  03/10/2024  203.0            TRESPASS 3, CRIMINAL  352.0
#
# ...

# %%
unique_crimes
# Out:
# ['(null)',
#  'A.B.C.,FALSE PROOF OF AGE',
#  'ACCOSTING,FRAUDULENT',
#  'ADM.CODE,UNCLASSIFIED MISDEMEA',
#  'ADM.CODE,UNCLASSIFIED VIOLATIO',
#  'AGGRAVATED CRIMINAL CONTEMPT',
#  'AGGRAVATED GRAND LARCENY OF ATM',
#  'AGGRAVATED HARASSMENT 1',
#  'AGGRAVATED HARASSMENT 2',
#  'AGGRAVATED SEXUAL ASBUSE',
#  'AGRICULTURE & MARKETS LAW,UNCL',
#  'ALCOHOLIC BEVERAGE CONTROL',
#  'ALCOHOLIC BEVERAGE CONTROL LAW',
#  'ALCOHOLIC BEVERAGES,PUBLIC CON',
#  'ARSON 2,3,4',
#  'ASSAULT 2,1,UNCLASSIFIED',
#  'ASSAULT 3',
#  'ASSAULT POLICE/PEACE OFFICER',
#  'ASSEMBLY,UNLAWFUL',
#  'BAIL JUMPING 1 & 2',
#  'BAIL JUMPING 3',
#  'BRIBERY,COMMERCIAL',
#  'BRIBERY,FRAUD',
#  'BRIBERY,PUBLIC ADMINISTRATION',
#  'BURGLARS TOOLS,UNCLASSIFIED',
#  'BURGLARY,RESIDENCE,NIGHT',
#  'BURGLARY,UNCLASSIFIED,UNKNOWN',
#  'CANNABIS POSSESSION',
#  'CANNABIS POSSESSION, 2&1',
#  'CANNABIS POSSESSION, 3',
#  'CANNABIS SALE, 2&1',
#  'CANNABIS SALE, 3',
#  'CAUSE SPI/KILL ANIMAL',
#  'CHECK,BAD',
# ...

# %%
top_ten_crimes = crime_df['PD_DESC'].value_counts().head(10)
age = crime_df['AGE_GROUP'].value_counts()
race = crime_df['PERP_RACE'].value_counts()

# %%
assault_3 = "ASSAULT 3"
assault_df = crime_df[crime_df["PD_DESC"].str.match(assault_3)]
cleaned_assault = assault_df.drop(['KY_CD', 'LAW_CODE', 'LAW_CAT_CD', 'JURISDICTION_CODE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'], axis=1)
cleaned_assault
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD    PD_DESC                     OFNS_DESC  \
# 2       279895750  01/03/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 7       281338081  01/30/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 15      281544391  02/02/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 16      282248602  02/15/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 19      282453654  02/19/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# ...           ...         ...    ...        ...                           ...
# 63577   283886995  03/17/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 63581   283477141  03/09/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 63585   284545584  03/30/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 63600   283606730  03/12/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 63613   283819808  03/15/2024  101.0  ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
#
# ...

# %%
cleaned_crime_df = crime_df.drop(['KY_CD', 'LAW_CODE', 'LAW_CAT_CD', 'JURISDICTION_CODE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'], axis=1)
cleaned_crime_df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  \
# 0       280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED
# 1       279805419  01/02/2024  157.0                          RAPE 1
# 2       279895750  01/03/2024  101.0                       ASSAULT 3
# 3       280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI
# 4       280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED
# ...           ...         ...    ...                             ...
# 63616   282877412  02/27/2024  339.0  LARCENY,PETIT FROM OPEN AREAS,
# 63617   283628088  03/12/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI
# 63618   283387006  03/07/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED
# 63619   283013910  03/01/2024  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN
# 63620   283495531  03/10/2024  203.0            TRESPASS 3, CRIMINAL
#
#                           OFNS_DESC ARREST_BORO  ARREST_PRECINCT AGE_GROUP  \
# ...
